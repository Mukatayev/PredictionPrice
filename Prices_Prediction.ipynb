# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import
data = pd.read_csv("C:/Users/Adila/Desktop/Data/kc_house_data.csv")
data = pd.DataFrame(data)

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
data.shape
# Out:
# (21613, 21)

# %%
# Preparation Data
# Duplicates
data.count()
# Out:
# id               21613
# date             21613
# price            21613
# bedrooms         21613
# bathrooms        21613
# sqft_living      21613
# sqft_lot         21613
# floors           21613
# waterfront       21613
# view             21613
# condition        21613
# grade            21613
# sqft_above       21613
# sqft_basement    21613
# yr_built         21613
# yr_renovated     21613
# zipcode          21613
# lat              21613
# long             21613
# sqft_living15    21613
# sqft_lot15       21613
# dtype: int64

# %%
# NAN Missing
data.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
corr = data.corr()

# %%
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_4c7fb488_1ec2_11eb_b710_7c2a3179a5b2row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4c7fb488_1ec2_11eb_b710_7c2a3179a5b2row0_col1 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_4c7fb488_1ec2_11eb_b710_7c2a3179a5b2row0_col2 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_4c7fb488_1ec2_11eb_b710_7c2a3179a5b2row0_col3 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_4c7fb488_1ec2_11eb_b710_7c2a3179a5b2row0_col4 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_4c7fb488_1ec2_11eb_b710_7c2a3179a5b2row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4c7fb488_1ec2_11eb_b710_7c2a3179a5b2row0_col6 {
#             background-color:  #84a7fc;
#             color:  #000000;
# ...

# %%
# Delete the less corr variable to the price (<0.5)
data.drop(["id",
           "date",
           "bedrooms",
           "sqft_lot","floors",
           "waterfront","view",
           "condition",
           "sqft_basement",
           "yr_built",
           "yr_renovated",
           "zipcode",
           "lat","long",
           "sqft_lot15"],axis=1, inplace=True)

# %%
# Reg eq y = mx + c
y = data["price"]
x = data.drop("price",axis=1)
x
# Out:
#        bathrooms  sqft_living  grade  sqft_above  sqft_living15
# 0           1.00         1180      7        1180           1340
# 1           2.25         2570      7        2170           1690
# 2           1.00          770      6         770           2720
# 3           3.00         1960      7        1050           1360
# 4           2.00         1680      8        1680           1800
# ...          ...          ...    ...         ...            ...
# 21608       2.50         1530      8        1530           1530
# 21609       2.50         2310      8        2310           1830
# 21610       0.75         1020      7        1020           1020
# 21611       2.50         1600      8        1600           1410
# 21612       0.75         1020      7        1020           1020
#
# [21613 rows x 5 columns]

# %%
# Train and Test 
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split (x, y, test_size = 0.33, random_state = 100)

#Building Linar regression Models
from sklearn.linear_model import LinearRegression

#Linear Regression
reg_model = LinearRegression()
reg_model.fit(xtrain, ytrain)

# Prediction
prediction = reg_model.predict(xtest)

# %%
plt.xlabel("ytest")
plt.ylabel("predicted values")
plt.scatter(ytest,prediction)

# %%
diff_show = pd.DataFrame({"Actual":ytest, "Predicted" : prediction})
diff_show
# Out:
#          Actual      Predicted
# 19836  285000.0  497373.777282
# 10442  239950.0  334984.750441
# 20548  460000.0  696224.156777
# 11014  397500.0  367107.445507
# 4138   545000.0  490171.242280
# ...         ...            ...
# 16087  180000.0  364409.159706
# 20979  399900.0  603279.808216
# 3880   357000.0  346931.951179
# 8325   577500.0  575375.944480
# 13816  405000.0  291528.057248
#
# [7133 rows x 2 columns]

# %%
# R square 
from sklearn.metrics import r2_score
r2_score(ytest,prediction)
# Out:
# 0.5473511957662898

# %%
# 54% rel btw model and depend

# %%
# Model 2 
data = pd.read_csv("C:/Users/Adila/Desktop/Data/kc_house_data.csv")
data = pd.DataFrame(data)
data.drop(["date"],axis=1, inplace=True)

y = data["price"]
x = data.drop("price",axis=1)
x.dtypes
# Out:
# id                 int64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
#Train and Test Sets
from sklearn.model_selection import train_test_split

xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
reg_model2 = LinearRegression()
reg_model2.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
# Prediction
prediction = reg_model2.predict(xtest)

# %%
plt.xlabel("ytest")
plt.ylabel("predicted values")
plt.scatter(ytest,prediction)

plot_show = pd.DataFrame({"Actual":ytest, "Predicted" : prediction})
plot_show
# Out:
#           Actual     Predicted
# 735     365000.0  4.630006e+05
# 2830    865000.0  7.451182e+05
# 4106   1038000.0  1.235194e+06
# 16218  1490000.0  1.654699e+06
# 19964   711000.0  7.282665e+05
# ...          ...           ...
# 11144   650000.0  8.593758e+05
# 17803   705000.0  6.058149e+05
# 268     272500.0  4.463235e+05
# 518    2250000.0  1.329623e+06
# 8482    330000.0  4.337700e+05
#
# [5404 rows x 2 columns]

# %%
r2_score(ytest,prediction)
# Out:
# 0.704868895235703

# %%
# 70 %

# %%
# Model Reg Simple
data = pd.read_csv("C:/Users/Adila/Desktop/Data/kc_house_data.csv")
data = pd.DataFrame(data)

y = data["price"]
x = data["sqft_living"]
x.dtypes
# Out:
# dtype('int64')

# %%
x
# Out:
# 0        1180
# 1        2570
# 2         770
# 3        1960
# 4        1680
#          ...
# 21608    1530
# 21609    2310
# 21610    1020
# 21611    1600
# 21612    1020
# Name: sqft_living, Length: 21613, dtype: int64

# %%
x = np.array(x).reshape(-1, 1)

# %%
y = np.array(y)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.4, random_state=50)

# %%
model3 = LinearRegression()
model3.fit(xtrain, ytrain)

prediction = model3.predict(xtest)

# %%
# Training test
plt.scatter(xtrain, ytrain)
plt.plot(xtrain, model3.predict(xtrain), color = 'red')
plt.show()

# %%
#Test Results 
plt.scatter(xtest, ytest)
plt.plot(xtrain, model3.predict(xtrain), color = 'red')
plt.show()

# %%
r2_score(ytest, prediction)
# Out:
# 0.4944752766229097

# %%
# Summary
# Model1 with corr (>0,5) 5 features -> 54 %
# Model2 with all features -> 70 %
# Model3 simple with highest corr [sqft_living] -> 49 %
